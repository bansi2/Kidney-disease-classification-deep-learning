# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing"

# %%
fileId = url.split('/')[-2]

# %%
prefix = "https://drive.google.com/uc?/export=download&id="
gdown.download(prefix+fileId, "KidneyCT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3&confirm=t&uuid=1af48598-825d-47d3-881e-cb9dd43a0a11
# To: d:\Deep Learning\Kidney-disease-classification-deep-learning\research\KidneyCT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:13<00:00, 4.30MB/s]
# 'KidneyCT-Scan-data.zip'
